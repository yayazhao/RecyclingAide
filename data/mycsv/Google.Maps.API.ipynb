# %% [markdown]
# 30 Days of Python - Day 20 - Using Google Maps Geocoding and Places API - Python TUTORIAL
# https://www.youtube.com/watch?v=ckPEY2KppHc
#
# \\$ pipenv install jupyter request pandas
#
# \\$ pipenv run jupyter notebook
#
# ### Steps
# 1. Sign up for Google Clooud
# 2. Create a project inside Google Cloud
# 3. Activate our API services -> Geocoding API & Places API
# 4. Get API Key & Restrict

# %%
api_key='AIzaSyA3IL6n1GRc5dWai6m53fHe4k818Cgf2OA'

# %% [markdown]
# ### Client
# 1. Google Maps API Docs https://developers.google.com/maps/documentation/geocoding/overview
# 2. Geocoding API
# 3. Places API

# %%
from urllib.parse import urlencode
import requests
import pandas as pd

# %%
data_type='json'
endpoint=f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
params={"address": "1600 Amphitheatre Parkway, Mountain View, CA", "key": api_key}
url_params = urlencode(params)
print(url_params)
url = f"{endpoint}?{url_params}"
print(url)
# Out:
# address=1600+Amphitheatre+Parkway%2C+Mountain+View%2C+CA&key=AIzaSyA3IL6n1GRc5dWai6m53fHe4k818Cgf2OA
# https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway%2C+Mountain+View%2C+CA&key=AIzaSyA3IL6n1GRc5dWai6m53fHe4k818Cgf2OA

# %%
def extract_lat_lng(address_or_postalcode, data_type='json'):
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {"address": address_or_postalcode, "key": api_key}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(200, 299):
        return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except:
        pass
    return latlng.get("lat"), latlng.get('lng')

# %%
extract_lat_lng("207 Glenmore Rd., Chapel Hill, NC, 27516")
# Out:
# (35.95951549999999, -79.0614822)

# %%
df = pd.read_csv('SW_FacilityList.csv')
df['lat'] = 0.0
df['lng'] = 0.0

# %%
print(df.iloc[0]['Address'], df.iloc[0]['City'])
df.loc[0, "lat"] = 1.123
print(df.iloc[0]['lat'])
# Out:
# 1168 Porter Avenue Haw River
# 1.123

# %%
nRows, nCols = df.shape
for row in range(nRows):
    addr = f"{df.iloc[row]['Address']}, {df.iloc[row]['City']}, NC"
    lat, lng = extract_lat_lng(addr)
    df.loc[row, "lat"] = lat
    df.loc[row, "lng"] = lng
df
# Out:
#        County     Waste Activity               Permit  \
# 0    Alamance   Medical    Incin        0102-INCIN-M-
# 1    Alamance        CD       LF       0104-CDLF-1993
# 2    Alamance       MSW       LF      0104-MSWLF-1994
# 3    Alamance        CD       LF       0105-CDLF-1998
# 4    Alamance      LCID       TP         0106-TP-2012
# ..        ...       ...      ...                  ...
# 392    Wilson       MSW    Trans  9806T-TRANSFER-1997
# 393    Wilson       MSW    Trans  9808T-TRANSFER-2000
# 394    Wilson        CD       LF           9809-CDLF-
# 395    Wilson  Type III  Compost    9810-COMPOST-2016
# 396    Yadkin       MSW    Trans  9903T-TRANSFER-1994
#
#                                              Name  Status  \
# 0                                Stericycle, Inc.  Active
# 1                         Austin Quarter C&D Unit  Active
# 2                     Austin Quarter SWM Facility  Active
# 3                             Cobles C&D Landfill  Active
# ...

# %%
df.to_csv('SW_FacilityList_LatLng.csv')
